# %% [markdown]
# # Crime rate and House Prices in Ames City:
# In their paper "Crime and Property Values: Evidence from the 1990s Crime Drop” Devin and Jaren Pope bring statistical evidence that crime drop in the 90's in the USA had a postive coraletion on the housing prices in the US. They claim that "a drop in violent crime by 100 per 10,000 people is associated with a 5.5% increase in housing values."*
# In this notebook we will try and check of this claim holds for Ames's, Iowa real estate markt in the begining of the 21th centurey. In order to test this conjecture we picked a sample of 4 years out of 18. We used two databases:
# 1)Ames real estate sell prices from kaggle: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview
# 2)The FBI's Uniform Crime Reporting Programm: https://www.fbi.gov/services/cjis/ucr/
# To put it to more percise words our null hypothesis is that for the years 2006 till 2010 as a whole for an annual drop of 100 cases of proprety crime for 10,000 residences, we will see increase of around 5.5%. Ergo:
# $$H_0 : S(Amces) = 5.5\%$$
#
# Method:
# I .We will used the our databaces to calculate the annual change in proprerty crime rates and in sales prices drawing the mean of of those years.
# II. run a simulation giving Devin and Jaren Pope stitical anylisis and showing if the information drawn is statistically significant.
#
#
# Work flow:
# 1:first we lay the fundamntals
# 2.importaing databaces and ajusting them into desicred from
# In order to do that
# *Pope, Devin G., and Jaren C. Pope. “Crime and Property Values: Evidence from the 1990s Crime Drop.” Regional Science and Urban Economics 42, no. 1–2 (January 2012): 186.

# %% [markdown]
# ## 1. laying down the fundmantals

# %%
#Libraries Used
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ###  Basic formulas for Sample statistic
# We need some basic formulas to calculate the mean, the standart deviation and the standart score for samples that can take pandas Series

# %%
def mean_sample(ser):
    sum_ser, counter = 0, 0
    for i in list(ser):
        counter+=1
        sum_ser+=i
    return round(sum_ser / (counter-1), 2)

# %%
def std_sample(ser):
    mean = mean_sample(ser)
    sigma, counter = 0
    for i in lst(ser):
        counter+=1
        sigma+=(i-mean)**2
    return (sigma/ (counter-1))**0.5

# %%
# p value
def Sd_score_sample(ser, result):
    mean = mean_sample(ser)
    std = std_sample(ser)
    return (result-mean)/std

# %%
df = pd.read_csv("Crime_stats_Ames_City.csv")

# %%
# Out:
#    Year  Months  Population  Violent crime total  \
# 0  1988      12       44021                   58
# 1  1989      12       43840                   50
# 2  1990      12       47198                   72
# 3  1992      12       47796                   35
# 4  1993      12       46854                   43
#
#    Murder and nonnegligent Manslaughter  Legacy rape  Robbery  \
# 0                                     0            8        4
# 1                                     1           10        9
# 2                                     0           27       13
# 3                                     1            8        5
# 4                                     1           16        5
#
#    Aggravated assault  Property crime total  Burglary  ...  \
# 0                  46                  1587       223  ...
# 1                  30                  1477       248  ...
# 2                  32                  1464       182  ...
# 3                  21                  1480       186  ...
# 4                  21                  1602       144  ...
#
#    Motor vehicle theft  Property crime rate  Burglary rate  \
# 0                   62               3605.1          506.6
# 1                   43               3369.1          565.7
# 2                   63               3101.8          385.6
# 3                   24               3096.5          389.2
# 4                   69               3419.1          307.3
#
#    Larceny-theft rate  Motor vehicle theft rate  Violent Crime rate  \
# 0              2957.7                     140.8               131.8
# 1              2705.3                      98.1               114.1
# 2              2582.7                     133.5               152.5
# 3              2657.1                      50.2                73.2
# 4              2964.5                     147.3                91.8
#
#    Murder and nonnegligent manslaughter rate  rape rate  Robbery rate  \
# 0                                        0.0       18.2           9.1
# 1                                        2.3       22.8          20.5
# 2                                        0.0       57.2          27.5
# 3                                        2.1       16.7          10.5
# 4                                        2.1       34.1          10.7
#
#    Aggravated assault rate
# 0                    104.5
# 1                     68.4
# 2                     67.8
# 3                     43.9
# 4                     44.8
#
# [5 rows x 21 columns]

# %%
df =df[["Year","Population","Property crime rate","Burglary rate","Larceny-theft rate","Violent Crime rate","Murder and nonnegligent manslaughter rate","rape rate","Aggravated assault rate"]]

# %% [markdown]
# ## chnaging the rates for 100,000 people in a year to 10,000 in a year

# %%
to_div_by_10 = ["Property crime rate","Burglary rate","Larceny-theft rate","Violent Crime rate","Murder and nonnegligent manslaughter rate","rape rate","Aggravated assault rate"]
for i in to_div_by_10:
    df[i] =df[i]/10

# %%
df.rename(columns ={"Murder and nonnegligent manslaughter rate":"Murder rate", "rape rate":"Rape rate"}, inplace=True)

# %%
df
# Out:
#     Year  Population  Property crime rate  Burglary rate  Larceny-theft rate  \
# 0   1988       44021               360.51          50.66              295.77
# 1   1989       43840               336.91          56.57              270.53
# 2   1990       47198               310.18          38.56              258.27
# 3   1992       47796               309.65          38.92              265.71
# 4   1993       46854               341.91          30.73              296.45
# 5   1994       47103               350.72          43.52              295.52
# 6   1995       46776               347.40          32.07              303.15
# 7   1996       46940               314.87          31.10              270.98
# 8   1997       46940               269.28          28.97              231.15
# 9   1998       47884               211.55          23.39              176.47
# 10  1999       48533               351.93          16.90              327.82
# 11  2000       50731               300.01          18.33              272.02
# 12  2001       50676               277.84          34.93              228.91
# 13  2002       50912               381.25          47.93              318.98
# 14  2003       51040               340.52          42.12              281.54
# 15  2004       53472               295.86          72.75              207.96
# 16  2005       52529               292.60          88.52              195.70
# 17  2006       52541               278.83          69.09              201.94
# 18  2007       51622               310.53          96.86              201.66
# 19  2008       55249               296.11          62.63              222.27
# 20  2009       57173               282.13          48.80              224.76
# 21  2010       58965               263.89          49.01              206.39
# 22  2011       59274               281.74          59.22              213.08
# 23  2012       59271               245.31          49.10              190.99
# 24  2013       61193               235.65          36.61              193.32
# 25  2014       62514               178.68          30.55              144.13
#
#     Violent Crime rate  Murder rate  Rape rate  Aggravated assault rate
# 0                13.18         0.00       1.82                    10.45
# 1                11.41         0.23       2.28                     6.84
# 2                15.25         0.00       5.72                     6.78
# 3                 7.32         0.21       1.67                     4.39
# 4                 9.18         0.21       3.41                     4.48
# 5                12.10         0.00       2.97                     8.49
# 6                10.26         0.00       1.07                     8.34
# 7                 8.10         0.00       2.34                     5.33
# 8                 7.67         0.21       1.28                     5.97
# 9                 7.94         0.00       3.34                     3.97
# 10                6.18         0.21       1.44                     3.50
# 11               13.80         0.00       3.15                     8.87
# 12               19.73         0.20       2.57                    14.21
# 13               26.32         0.00       6.87                    16.89
# 14               54.66         0.00       4.90                    48.39
# 15               24.12         0.00       4.11                    17.58
# 16               18.66         0.00       2.67                    13.33
# 17               27.98         0.00       4.57                    20.17
# 18               38.74         0.39       3.49                    32.54
# 19               31.31         0.72       4.71                    24.07
# 20               30.96         0.00       4.02                    24.31
# 21               30.02         0.17       4.07                    24.08
# 22               30.03         0.00       3.04                    25.31
# 23               13.16         0.00       5.40                     6.58
# 24               15.36         0.00       5.72                     7.84
# 25               12.00         0.00       3.68                     5.92

# %%
df["Property crime rate"].describe()
# Out:
# count     26.000000
# mean     298.686923
# std       47.591664
# min      178.680000
# 25%      278.087500
# 50%      298.060000
# 75%      339.617500
# max      381.250000
# Name: Property crime rate, dtype: float64

# %%
df
# Out:
#     Year  Population  Property crime rate  Burglary rate  Larceny-theft rate  \
# 0   1988       44021               360.51          50.66              295.77
# 1   1989       43840               336.91          56.57              270.53
# 2   1990       47198               310.18          38.56              258.27
# 3   1992       47796               309.65          38.92              265.71
# 4   1993       46854               341.91          30.73              296.45
# 5   1994       47103               350.72          43.52              295.52
# 6   1995       46776               347.40          32.07              303.15
# 7   1996       46940               314.87          31.10              270.98
# 8   1997       46940               269.28          28.97              231.15
# 9   1998       47884               211.55          23.39              176.47
# 10  1999       48533               351.93          16.90              327.82
# 11  2000       50731               300.01          18.33              272.02
# 12  2001       50676               277.84          34.93              228.91
# 13  2002       50912               381.25          47.93              318.98
# 14  2003       51040               340.52          42.12              281.54
# 15  2004       53472               295.86          72.75              207.96
# 16  2005       52529               292.60          88.52              195.70
# 17  2006       52541               278.83          69.09              201.94
# 18  2007       51622               310.53          96.86              201.66
# 19  2008       55249               296.11          62.63              222.27
# 20  2009       57173               282.13          48.80              224.76
# 21  2010       58965               263.89          49.01              206.39
# 22  2011       59274               281.74          59.22              213.08
# 23  2012       59271               245.31          49.10              190.99
# 24  2013       61193               235.65          36.61              193.32
# 25  2014       62514               178.68          30.55              144.13
#
#     Violent Crime rate  Murder rate  Rape rate  Aggravated assault rate  \
# 0                13.18         0.00       1.82                    10.45
# 1                11.41         0.23       2.28                     6.84
# 2                15.25         0.00       5.72                     6.78
# 3                 7.32         0.21       1.67                     4.39
# 4                 9.18         0.21       3.41                     4.48
# 5                12.10         0.00       2.97                     8.49
# 6                10.26         0.00       1.07                     8.34
# 7                 8.10         0.00       2.34                     5.33
# 8                 7.67         0.21       1.28                     5.97
# 9                 7.94         0.00       3.34                     3.97
# 10                6.18         0.21       1.44                     3.50
# 11               13.80         0.00       3.15                     8.87
# 12               19.73         0.20       2.57                    14.21
# 13               26.32         0.00       6.87                    16.89
# 14               54.66         0.00       4.90                    48.39
# 15               24.12         0.00       4.11                    17.58
# 16               18.66         0.00       2.67                    13.33
# 17               27.98         0.00       4.57                    20.17
# 18               38.74         0.39       3.49                    32.54
# 19               31.31         0.72       4.71                    24.07
# 20               30.96         0.00       4.02                    24.31
# 21               30.02         0.17       4.07                    24.08
# 22               30.03         0.00       3.04                    25.31
# 23               13.16         0.00       5.40                     6.58
# 24               15.36         0.00       5.72                     7.84
# 25               12.00         0.00       3.68                     5.92
#
#     Year_before
# 0          1987
# 1          1988
# 2          1989
# 3          1991
# 4          1992
# 5          1993
# 6          1994
# 7          1995
# 8          1996
# 9          1997
# 10         1998
# 11         1999
# 12         2000
# 13         2001
# 14         2002
# 15         2003
# 16         2004
# 17         2005
# 18         2006
# 19         2007
# 20         2008
# 21         2009
# 22         2010
# 23         2011
# 24         2012
# 25         2013

# %%
df = df.assign(Year_before = lambda x : x["Year"] - 1)

# %%
df_change = df[["Year", "Population","Property crime rate", "Year_before"]]

# %%
df_change
# Out:
#     Year  Population  Property crime rate  Year_before
# 0   1988       44021               360.51         1987
# 1   1989       43840               336.91         1988
# 2   1990       47198               310.18         1989
# 3   1992       47796               309.65         1991
# 4   1993       46854               341.91         1992
# 5   1994       47103               350.72         1993
# 6   1995       46776               347.40         1994
# 7   1996       46940               314.87         1995
# 8   1997       46940               269.28         1996
# 9   1998       47884               211.55         1997
# 10  1999       48533               351.93         1998
# 11  2000       50731               300.01         1999
# 12  2001       50676               277.84         2000
# 13  2002       50912               381.25         2001
# 14  2003       51040               340.52         2002
# 15  2004       53472               295.86         2003
# 16  2005       52529               292.60         2004
# 17  2006       52541               278.83         2005
# 18  2007       51622               310.53         2006
# 19  2008       55249               296.11         2007
# 20  2009       57173               282.13         2008
# 21  2010       58965               263.89         2009
# 22  2011       59274               281.74         2010
# 23  2012       59271               245.31         2011
# 24  2013       61193               235.65         2012
# 25  2014       62514               178.68         2013

# %%
df_change = df_change.merge(df_change, how = "inner", right_on="Year", left_on="Year_before")

# %% [markdown]
# ## Merging with self and calulcating change

# %%
df_change.drop(['Year_before_x', 'Year_y', "Year_before_y"], axis=1)
# Out:
#     Year_x  Population_x  Property crime rate_x  Population_y  \
# 0     1989         43840                 336.91         44021
# 1     1990         47198                 310.18         43840
# 2     1993         46854                 341.91         47796
# 3     1994         47103                 350.72         46854
# 4     1995         46776                 347.40         47103
# 5     1996         46940                 314.87         46776
# 6     1997         46940                 269.28         46940
# 7     1998         47884                 211.55         46940
# 8     1999         48533                 351.93         47884
# 9     2000         50731                 300.01         48533
# 10    2001         50676                 277.84         50731
# 11    2002         50912                 381.25         50676
# 12    2003         51040                 340.52         50912
# 13    2004         53472                 295.86         51040
# 14    2005         52529                 292.60         53472
# 15    2006         52541                 278.83         52529
# 16    2007         51622                 310.53         52541
# 17    2008         55249                 296.11         51622
# 18    2009         57173                 282.13         55249
# 19    2010         58965                 263.89         57173
# 20    2011         59274                 281.74         58965
# 21    2012         59271                 245.31         59274
# 22    2013         61193                 235.65         59271
# 23    2014         62514                 178.68         61193
#
#     Property crime rate_y
# 0                  360.51
# 1                  336.91
# 2                  309.65
# 3                  341.91
# 4                  350.72
# 5                  347.40
# 6                  314.87
# 7                  269.28
# 8                  211.55
# 9                  351.93
# 10                 300.01
# 11                 277.84
# 12                 381.25
# 13                 340.52
# 14                 295.86
# 15                 292.60
# 16                 278.83
# 17                 310.53
# 18                 296.11
# 19                 282.13
# 20                 263.89
# 21                 281.74
# 22                 245.31
# 23                 235.65

# %%
df_change = df_change.assign(Population_change= lambda x: x["Population_x"] - x["Population_y"])
df_change = df_change.assign(Property_crime_rate_change= lambda x: x["Property crime rate_x"] - x["Property crime rate_y"])  
df_change = df_change.drop(["Year_y", "Population_y", "Property crime rate_y", "Year_before_y", "Year_before_x"], axis=1)
df_change.rename(columns ={"Year_x":"Year", "Population_x":"Population", "Property crime rate_x": "Property crime rate"}, inplace=True)

# %%
df_2006_2007_change = df_change.loc[(df_change["Year"] >= 2006) & (df_change["Year"] <= 2010)]

# %%
df_2006_2007_change
# Out:
#     Year  Population  Property crime rate  Population_change  \
# 15  2006       52541               278.83                 12
# 16  2007       51622               310.53               -919
# 17  2008       55249               296.11               3627
# 18  2009       57173               282.13               1924
# 19  2010       58965               263.89               1792
#
#     Property_crime_rate_change
# 15                      -13.77
# 16                       31.70
# 17                      -14.42
# 18                      -13.98
# 19                      -18.24

# %%
df_mean_by_Year= pd.read_csv("Mean_by_Year.csv")

# %%
df_mean_by_Year = df_mean_by_Year[["YrSold", "SalePrice"]]
df_mean_by_Year=df_mean_by_Year.assign(Year_before= lambda x : x["YrSold"] - 1)

# %%
df_mean_by_Year
# Out:
#    YrSold      SalePrice  Year_before
# 0    2006  182020.929487         2005
# 1    2007  186063.151976         2006
# 2    2008  177227.602649         2007
# 3    2009  179432.103550         2008
# 4    2010  177109.208092         2009

# %%
df_mean_by_Year = df_mean_by_Year.merge(df_mean_by_Year, how = "inner", right_on="YrSold", left_on="Year_before").assign(avg_price_change=lambda x : x["SalePrice_x"] - x["SalePrice_y"]).drop(['Year_before_x', 'YrSold_y', "Year_before_y", "SalePrice_y" ], axis=1).rename(columns ={"YrSold_x":"Year", "SalePrice_x":"SalePrice"})

# %%
df_mean_by_Year
# Out:
#    Year      SalePrice  avg_price_change
# 0  2007  186063.151976       4042.222489
# 1  2008  177227.602649      -8835.549327
# 2  2009  179432.103550       2204.500901
# 3  2010  177109.208092      -2322.895458

# %%
df_cal = df_2006_2007_change.merge(df_mean_by_Year,how = "inner", right_on="Year", left_on="Year" )

# %%
df_cal = df_cal.assign(avg_price_change_pre= lambda x: x["avg_price_change"] * 100 / x["SalePrice"])

# %%
df_cal
# Out:
#    Year  Population  Property crime rate  Population_change  \
# 0  2007       51622               310.53               -919
# 1  2008       55249               296.11               3627
# 2  2009       57173               282.13               1924
# 3  2010       58965               263.89               1792
#
#    Property_crime_rate_change      SalePrice  avg_price_change  \
# 0                       31.70  186063.151976       4042.222489
# 1                      -14.42  177227.602649      -8835.549327
# 2                      -13.98  179432.103550       2204.500901
# 3                      -18.24  177109.208092      -2322.895458
#
#    avg_price_change_pre
# 0              2.172500
# 1             -4.985425
# 2              1.228599
# 3             -1.311561

# %%
#for 2007
var =100/df_cal["Property_crime_rate_change"][0] 
(df_cal["avg_price_change"][0]*var)/(df_cal["SalePrice"][0]*var)
# Out:
# 0.021725002750854535

# %%
df_cal.describe()
# Out:
#               Year   Population  Property crime rate  Population_change  \
# count     4.000000      4.00000             4.000000           4.000000
# mean   2008.500000  55752.25000           288.165000        1606.000000
# std       1.290994   3143.91045            19.908232        1879.342616
# min    2007.000000  51622.00000           263.890000        -919.000000
# 25%    2007.750000  54342.25000           277.570000        1114.250000
# 50%    2008.500000  56211.00000           289.120000        1858.000000
# 75%    2009.250000  57621.00000           299.715000        2349.750000
# max    2010.000000  58965.00000           310.530000        3627.000000
#
#        Property_crime_rate_change      SalePrice  avg_price_change  \
# count                    4.000000       4.000000          4.000000
# mean                    -3.735000  179958.016567      -1227.930349
# std                     23.700658    4207.934281       5733.844269
# min                    -18.240000  177109.208092      -8835.549327
# 25%                    -15.375000  177198.004010      -3951.058925
# 50%                    -14.200000  178329.853100        -59.197278
# 75%                     -2.560000  181089.865657       2663.931298
# max                     31.700000  186063.151976       4042.222489
#
#        avg_price_change_pre
# count              4.000000
# mean              -0.723972
# std                3.199340
# min               -4.985425
# 25%               -2.230027
# 50%               -0.041481
# 75%                1.464574
# max                2.172500

# %%
mean_property_crime_rate_change = mean_sample(df_cal["Property_crime_rate_change"])
mean_property_crime_rate_change
# Out:
# -4.98

# %%
mean_price_change = mean_sample(df_cal["avg_price_change"])
mean_price_change
# Out:
# -1637.24

# %%
mean_saleprice = mean_sample(df_cal["SalePrice"])
mean_saleprice
# Out:
# 239944.02

# %%
mean_price_change/mean_saleprice * 100
# Out:
# -0.6823424897190604

# %% [markdown]
# ## module

# %%
0.008

# %%
moudle = np.random.normal(5.5, 8, 100)

# %%
sns.distplot(moudle, rug=True)

# %%
ttest_1samp(moudle, -0.68)
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-307-64b58326cd14> in <module>
# ----> 1 ttest_1samp(moudle, -0.68)
#
# NameError: name 'ttest_1samp' is not defined

# %%
z_score = ((mean_price_change/mean_saleprice * 100) - 5.5) /8

# %%
z_score
# Out:
# -0.7727928112148825
